# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('240304 Training Assignment Dataset - Copy.csv')

# %%
df
# Out:
#             id  Gender   Age  Driving_License  Region_Code  \
# 0            1    Male  44.0              1.0         28.0
# 1            2    Male  76.0              1.0          3.0
# 2            3    Male  47.0              1.0         28.0
# 3            4    Male  21.0              1.0         11.0
# 4            5  Female  29.0              NaN         41.0
# ...        ...     ...   ...              ...          ...
# 381104  381105    Male  74.0              1.0         26.0
# 381105  381106    Male  30.0              1.0         37.0
# 381106  381107    Male  21.0              1.0         30.0
# 381107  381108  Female  68.0              1.0         14.0
# 381108  381109    Male  46.0              1.0         29.0
#
#         Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                      0.0   > 2 Years            Yes         40454.0
# 1                      0.0    1-2 Year             No         33536.0
# 2                      0.0   > 2 Years            Yes         38294.0
# 3                      1.0    < 1 Year             No         28619.0
# 4                      1.0    < 1 Year             No         27496.0
# ...                    ...         ...            ...             ...
# 381104                 1.0    1-2 Year             No         30170.0
# 381105                 1.0    < 1 Year             No         40016.0
# 381106                 1.0    < 1 Year             No         35118.0
# 381107                 0.0   > 2 Years            Yes         44617.0
# 381108                 0.0    1-2 Year             No         41777.0
#
#         Policy_Sales_Channel  Vintage  Response
# 0                       26.0    217.0         1
# 1                       26.0    183.0         0
# 2                       26.0     27.0         1
# 3                      152.0    203.0         0
# 4                      152.0     39.0         0
# ...                      ...      ...       ...
# 381104                  26.0     88.0         0
# 381105                 152.0    131.0         0
# 381106                 160.0    161.0         0
# 381107                 124.0     74.0         0
# 381108                  26.0    237.0         0
#
# [381109 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                378700 non-null  object
#  2   Age                   378590 non-null  float64
#  3   Driving_License       377925 non-null  float64
#  4   Region_Code           377876 non-null  float64
#  5   Previously_Insured    377901 non-null  float64
#  6   Vehicle_Age           377651 non-null  object
#  7   Vehicle_Damage        377833 non-null  object
#  8   Annual_Premium        377943 non-null  float64
#  9   Policy_Sales_Channel  379154 non-null  float64
#  10  Vintage               381014 non-null  float64
#  11  Response              381109 non-null  int64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 34.9+ MB

# %%
df.describe()
# Out:
#                   id           Age  Driving_License    Region_Code  \
# count  381109.000000  378590.00000    377925.000000  377876.000000
# mean   190555.000000      38.81855         0.997867      26.393619
# std    110016.836208      15.50903         0.046132      13.230413
# min         1.000000      20.00000         0.000000       0.000000
# 25%     95278.000000      25.00000         1.000000      15.000000
# 50%    190555.000000      36.00000         1.000000      28.000000
# 75%    285832.000000      49.00000         1.000000      35.000000
# max    381109.000000      85.00000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       377901.000000   377943.000000         379154.000000
# mean             0.458178    30563.769928            112.040878
# std              0.498249    17216.943211             54.200731
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24406.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39397.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381014.000000  381109.000000
# mean      154.344021       0.122563
# std        83.672192       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
df
# Out:
#             id  Gender   Age  Driving_License  Region_Code  \
# 0            1    Male  44.0              1.0         28.0
# 1            2    Male  76.0              1.0          3.0
# 2            3    Male  47.0              1.0         28.0
# 3            4    Male  21.0              1.0         11.0
# 4            5  Female  29.0              NaN         41.0
# ...        ...     ...   ...              ...          ...
# 381104  381105    Male  74.0              1.0         26.0
# 381105  381106    Male  30.0              1.0         37.0
# 381106  381107    Male  21.0              1.0         30.0
# 381107  381108  Female  68.0              1.0         14.0
# 381108  381109    Male  46.0              1.0         29.0
#
#         Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                      0.0   > 2 Years            Yes         40454.0
# 1                      0.0    1-2 Year             No         33536.0
# 2                      0.0   > 2 Years            Yes         38294.0
# 3                      1.0    < 1 Year             No         28619.0
# 4                      1.0    < 1 Year             No         27496.0
# ...                    ...         ...            ...             ...
# 381104                 1.0    1-2 Year             No         30170.0
# 381105                 1.0    < 1 Year             No         40016.0
# 381106                 1.0    < 1 Year             No         35118.0
# 381107                 0.0   > 2 Years            Yes         44617.0
# 381108                 0.0    1-2 Year             No         41777.0
#
#         Policy_Sales_Channel  Vintage  Response
# 0                       26.0    217.0         1
# 1                       26.0    183.0         0
# 2                       26.0     27.0         1
# 3                      152.0    203.0         0
# 4                      152.0     39.0         0
# ...                      ...      ...       ...
# 381104                  26.0     88.0         0
# 381105                 152.0    131.0         0
# 381106                 160.0    161.0         0
# 381107                 124.0     74.0         0
# 381108                  26.0    237.0         0
#
# [381109 rows x 12 columns]

# %%
df[df['Driving_License'] == 0.0].describe()
# Out:
#                   id         Age  Driving_License  Region_Code  \
# count     806.000000  806.000000            806.0   806.000000
# mean   192209.277916   65.555831              0.0    26.725806
# std    109437.577475   10.494659              0.0    12.053834
# min       564.000000   21.000000              0.0     0.000000
# 25%    106038.000000   59.000000              0.0    22.000000
# 50%    194866.500000   67.000000              0.0    28.000000
# 75%    285641.250000   73.750000              0.0    29.000000
# max    380918.000000   85.000000              0.0    50.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel     Vintage  \
# count          806.000000      806.000000            806.000000  806.000000
# mean             0.297767    34964.073201             60.635236  155.913151
# std              0.457560    18473.689758             48.780211   83.060779
# min              0.000000     2630.000000              3.000000   10.000000
# 25%              0.000000    27110.500000             26.000000   83.000000
# 50%              0.000000    35729.500000             26.000000  157.000000
# 75%              1.000000    45998.750000            124.000000  231.750000
# max              1.000000   111683.000000            163.000000  298.000000
#
#          Response
# count  806.000000
# mean     0.050868
# std      0.219866
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
df['Driving_License'] = df['Driving_License'].fillna(df['Driving_License'].mode())

# %%
df.isna().sum()
# Out:
# id                         0
# Gender                  2409
# Age                     2519
# Driving_License            0
# Region_Code             3233
# Previously_Insured      3208
# Vehicle_Age             3458
# Vehicle_Damage          3276
# Annual_Premium          3166
# Policy_Sales_Channel    1955
# Vintage                   95
# Response                   0
# dtype: int64

# %%
df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  377876.000000
# mean   190555.000000      38.818550         0.997885      26.393619
# std    110016.836208      15.457691         0.045939      13.230413
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       377901.000000   377943.000000         379154.000000
# mean             0.458178    30563.769928            112.040878
# std              0.498249    17216.943211             54.200731
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24406.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39397.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381014.000000  381109.000000
# mean      154.344021       0.122563
# std        83.672192       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
len(df['Vehicle_Damage'].unique())
# Out:
# 3

# %%
df.dtypes
# Out:
# id                        int64
# Gender                   object
# Age                     float64
# Driving_License         float64
# Region_Code             float64
# Previously_Insured      float64
# Vehicle_Age              object
# Vehicle_Damage           object
# Annual_Premium          float64
# Policy_Sales_Channel    float64
# Vintage                 float64
# Response                  int64
# dtype: object

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Vehicle_Damage'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
cleanup = {
    "Gender" : {"Male":0,"Female":1},
    "Vehicle_Age":{"> 2 Years":0,"1-2 Year":1,"< 1 Year":2},
    "Vehicle_Damage":{"No":0,"Yes":1}
}

# %%
df = df.replace(cleanup)

# %%
df.dtypes
# Out:
# id                        int64
# Gender                  float64
# Age                     float64
# Driving_License         float64
# Region_Code             float64
# Previously_Insured      float64
# Vehicle_Age             float64
# Vehicle_Damage          float64
# Annual_Premium          float64
# Policy_Sales_Channel    float64
# Vintage                 float64
# Response                  int64
# dtype: object

# %%
df.corr()
# Out:
#                             id    Gender       Age  Driving_License  \
# id                    1.000000  0.001131  0.001417        -0.000692
# Gender                0.001131  1.000000  0.145493        -0.018428
# Age                   0.001417  0.145493  1.000000        -0.079630
# Driving_License      -0.000692 -0.018428 -0.079630         1.000000
# Region_Code          -0.000584  0.000511  0.042947        -0.001161
# Previously_Insured    0.002340 -0.082019 -0.254604         0.014884
# Vehicle_Age          -0.000756 -0.160455 -0.765601         0.037288
# Vehicle_Damage       -0.001510  0.091833  0.267430        -0.016418
# Annual_Premium        0.002904  0.003474  0.067233        -0.011815
# Policy_Sales_Channel -0.002995 -0.111018 -0.576430         0.043775
# Vintage              -0.000610 -0.002420 -0.001352        -0.000863
# Response             -0.001368  0.052618  0.110870         0.010065
#
#                       Region_Code  Previously_Insured  Vehicle_Age  \
# id                      -0.000584            0.002340    -0.000756
# Gender                   0.000511           -0.082019    -0.160455
# Age                      0.042947           -0.254604    -0.765601
# Driving_License         -0.001161            0.014884     0.037288
# Region_Code              1.000000           -0.024524    -0.043986
# Previously_Insured      -0.024524            1.000000     0.380820
# Vehicle_Age             -0.043986            0.380820     1.000000
# Vehicle_Damage           0.028050           -0.824034    -0.396893
# Annual_Premium          -0.010599            0.004546    -0.041401
# Policy_Sales_Channel    -0.042762            0.219579     0.550543
# Vintage                 -0.002838            0.002704     0.002123
# Response                 0.010502           -0.341068    -0.221947
#
#                       Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# id                         -0.001510        0.002904             -0.002995
# Gender                      0.091833        0.003474             -0.111018
# Age                         0.267430        0.067233             -0.576430
# Driving_License            -0.016418       -0.011815              0.043775
# Region_Code                 0.028050       -0.010599             -0.042762
# Previously_Insured         -0.824034        0.004546              0.219579
# Vehicle_Age                -0.396893       -0.041401              0.550543
# Vehicle_Damage              1.000000        0.009173             -0.224559
# Annual_Premium              0.009173        1.000000             -0.113158
# Policy_Sales_Channel       -0.224559       -0.113158              1.000000
# Vintage                    -0.002168       -0.000641              0.000125
# Response                    0.354425        0.022476             -0.139039
#
#                        Vintage  Response
# id                   -0.000610 -0.001368
# Gender               -0.002420  0.052618
# Age                  -0.001352  0.110870
# Driving_License      -0.000863  0.010065
# Region_Code          -0.002838  0.010502
# Previously_Insured    0.002704 -0.341068
# Vehicle_Age           0.002123 -0.221947
# Vehicle_Damage       -0.002168  0.354425
# Annual_Premium       -0.000641  0.022476
# Policy_Sales_Channel  0.000125 -0.139039
# Vintage               1.000000 -0.001106
# Response             -0.001106  1.000000

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the 'Gender' column
# Replace 'df' with the actual name of your DataFrame

# Count occurrences of each gender
gender_counts = df['Gender'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

gender_counts = df['Gender'].value_counts()

print(gender_counts)
# Out:
# Gender
# 1.0    204727
# 0.0    173973
# Name: count, dtype: int64

# %%
cross_tab = pd.crosstab(df['Gender'], df['Vehicle_Damage'])
cross_tab_percent = cross_tab.apply(lambda x: x / x.sum() * 100, axis=1)

# %%
cross_tab_percent.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.title('Damage')
plt.xlabel('Damage (0 = No, 1 = Yes)')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend(title='Damage')
plt.show()

# %%
age_bins = [20, 30, 40, 50, 60, 70, 80, 90, 100]
age_labels = ['20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90-100']

# Cut the 'Age' column into bins and count occurrences in each bin
age_groups = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)
age_counts = age_groups.value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Age Groups')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
